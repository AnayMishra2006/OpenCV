# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image=cv2.imread('GiraffeConservationKenyaAWF.jpg')
print(image)
# Out:
# [[[202 178 166]
#   [214 190 172]
#   [215 190 170]
#   ...
#   [230 206 194]
#   [229 204 194]
#   [230 205 195]]
#
#  [[203 180 164]
#   [218 194 176]
#   [223 197 180]
#   ...
#   [239 216 201]
#   [237 214 199]
#   [237 214 199]]
#
#  [[197 176 155]
#   [213 189 171]
#   [222 196 179]
#   ...
#   [237 215 204]
#   [239 215 203]
#   [238 215 200]]
#
#  ...
#
#  [[ 95 139 176]
#   [ 99 143 180]
#   [102 147 181]
#   ...
#   [ 86 132 163]
#   [ 94 135 167]
#   [ 88 128 157]]
#
#  [[ 92 136 173]
#   [ 96 140 181]
#   [100 145 183]
#   ...
#   [ 89 137 165]
#   [102 143 175]
#   [ 97 131 161]]
#
#  [[ 90 138 172]
#   [ 93 141 183]
#   [ 98 147 187]
#   ...
#   [100 142 165]
#   [103 142 170]
#   [ 91 129 159]]]

# %%
image_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
grey_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
kernel_s=5
average_blur=cv2.blur(grey_image,(kernel_s,kernel_s))
plt.imshow(average_blur,cmap='grey')

# %%
gaussian_blur=cv2.GaussianBlur(grey_image,(kernel_s,kernel_s),0,0)  ##kernel_s should be an odd number always
plt.imshow(gaussian_blur,cmap='grey')

# %%
medianblur=cv2.medianBlur(grey_image,5)
plt.imshow(medianblur,cmap='grey')
